# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/home/veer/Desktop/Data_science_journey/Datas/ipl-matches.csv")

# %%
df.shape
# Out:
# (950, 20)

# %%
df.head(5)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
df['WinningTeam'].value_counts(ascending=True)
# Out:
# WinningTeam
# Rising Pune Supergiants          5
# Kochi Tuskers Kerala             6
# Lucknow Super Giants             9
# Rising Pune Supergiant          10
# Pune Warriors                   12
# Gujarat Titans                  12
# Punjab Kings                    13
# Gujarat Lions                   13
# Deccan Chargers                 29
# Delhi Capitals                  36
# Delhi Daredevils                67
# Sunrisers Hyderabad             75
# Kings XI Punjab                 88
# Rajasthan Royals                96
# Royal Challengers Bangalore    109
# Kolkata Knight Riders          114
# Chennai Super Kings            121
# Mumbai Indians                 131
# Name: count, dtype: int64

# %%
def man(mom):
    df1=df[df['Player_of_Match']==mom]
    return df1['Player_of_Match'].replace({mom:1}).sum()

# %%
man('HH Pandya')
# Out:
# 8

# %%
df[df['Player_of_Match']=='HH Pandya']
# Out:
#           ID       City        Date Season MatchNumber                  Team1  \
# 0    1312200  Ahmedabad  2022-05-29   2022       Final       Rajasthan Royals
# 50   1304070     Mumbai  2022-04-14   2022          24         Gujarat Titans
# 199  1178431     Mumbai  2019-05-05   2019          56  Kolkata Knight Riders
# 220  1178409      Delhi  2019-04-18   2019          34         Mumbai Indians
# 239  1175370     Mumbai  2019-04-03   2019          15         Mumbai Indians
# 277  1136597     Mumbai  2018-05-06   2018          37         Mumbai Indians
# 442   829805     Mumbai  2015-05-14   2015          51         Mumbai Indians
# 450   829789    Chennai  2015-05-08   2015          43    Chennai Super Kings
#
#                      Team2                               Venue  \
# 0           Gujarat Titans    Narendra Modi Stadium, Ahmedabad
# 50        Rajasthan Royals  Dr DY Patil Sports Academy, Mumbai
# 199         Mumbai Indians                    Wankhede Stadium
# ...

# %%
one=df['TossWinner'].value_counts()
one.max()
# Out:
# 123

# %%
t=df[df['TossDecision']=='bat']

# %%
t['TossWinner'].value_counts()
# Out:
# TossWinner
# Chennai Super Kings            55
# Mumbai Indians                 51
# Rajasthan Royals               37
# Kolkata Knight Riders          36
# Royal Challengers Bangalore    30
# Delhi Daredevils               29
# Sunrisers Hyderabad            28
# Kings XI Punjab                27
# Deccan Chargers                24
# Pune Warriors                  11
# Delhi Capitals                  8
# Gujarat Titans                  4
# Rising Pune Supergiants         3
# Kochi Tuskers Kerala            3
# Lucknow Super Giants            2
# Punjab Kings                    2
# Gujarat Lions                   1
# Name: count, dtype: int64
