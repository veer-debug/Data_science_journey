# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_excel('/home/veer/Desktop/Data_science_journey/Datas/supermarket.xlsx')

# %%
df1.head(10)
# Out:
#    index          Order Id        Date           Meal Id        Company Id  \
# 0      0  839FKFW2LLX4LMBB  27-05-2016  INBUX904GIHI8YBD  LJKS5NK6788CYMUU
# 1      1  97OX39BGVMHODLJM  27-09-2018  J0MMOOPP709DIDIE  LJKS5NK6788CYMUU
# 2      2  041ORQM5OIHTIU6L  24-08-2014  E4UJLQNCI16UX5CS  LJKS5NK6788CYMUU
# 3      3  YT796QI18WNGZ7ZJ  12-04-2014  C9SDFHF7553BE247  LJKS5NK6788CYMUU
# 4      4  6YLROQT27B6HRF4E  28-07-2015  48EQXS6IHYNZDDZ5  LJKS5NK6788CYMUU
# 5      5  AT0R4DFYYAFOC88Q  21-07-2014  W48JPR1UYWJ18NC6  LJKS5NK6788CYMUU
# 6      6  2DDN2LHS7G85GKPQ  29-04-2014  1MKLAKBOE3SP7YUL  LJKS5NK6788CYMUU
# 7      7  FM608JK1N01BPUQN  08-05-2014  E8WJZ1FOSKZD2MJN  36MFTZOYMTAJP1RK
# 8      8  CK331XXNIBQT81QL  23-05-2015  CTZSFFKQTY7SBZ4J  36MFTZOYMTAJP1RK
# 9      9  FESGKOQN2OZZWXY3  10-01-2016  US0NQYNNHS1SQJ4S  36MFTZOYMTAJP1RK
#
#                 Date of Meal  \
# 0  2016-05-31 07:00:00+02:00
# 1  2018-10-01 20:00:00+02:00
# 2  2014-08-23 14:00:00+02:00
# ...

# %%
df=pd.read_excel("https://onedrive.live.com/edit?id=61274F4F2C5C9D2A!558140&resid=61274F4F2C5C9D2A!558140&authkey=!AHJCzfugsOeX8yI&wdo=2&cid=61274f4f2c5c9d2a")

# %%
df = pd.read_excel("https://api.onedrive.com/v1.0/shares/u!aHR0cHM6Ly8xZHJ2Lm1zL3UvcyFBaXFkWEN4UFR5ZGhvb2c4Y2tMTi02Q3c1NWZ6SWc_ZT1FV2daNWQ/root/content")

# %%
df.sample(20)
# Out:
#                                                     name  \
# 63048                  If Only They Didn't Speak English
# 16818                                            You Say
# 71100                                         Confidence
# 67657                                Lerne das Aurasehen
# 63972                      Aphorismen zur Lebensweisheit
# 63562                                   Divided We Stand
# 51604                                 Retour aux sources
# 66079                          When Prayer Is a Struggle
# 73517                                     Never Leave Me
# 40058                     The Luminous Heart of Jonah S.
# 17943                                  North to Paradise
# 35945                              The Arts of Seduction
# 64601                                Do What You Believe
# 69899                                      Bhagavat Gita
# 14930                           Musikalische Architektur
# ...
