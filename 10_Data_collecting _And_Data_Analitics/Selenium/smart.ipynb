# %%
with open('smartprix.html','r',encoding='utf-8') as f:
    html = f.read()

# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
soup = BeautifulSoup(html,'lxml')

# %%
containers = soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'})

# %%
names = []
prices = []
ratings = []
sim = []
processor = []
ram = []
battery = []
display = []
camera = []
card = []
os = []

for i in soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'}):
    try:
        names.append(i.find('h2').text)
    except:
        names.append(np.nan)
    try:
        prices.append(i.find('span',{'class':'price'}).text)
    except:
        prices.append(np.nan)
    try:
        ratings.append(i.find('div',{'class':'score rank-2-bg'}).find('b').text)
    except:
        ratings.append(np.nan)
        
    x = i.find('ul',{'class':'sm-feat specs'}).find_all('li')
    try:
        sim.append(x[0].text)
    except:
        sim.append(np.nan)
    try:
        processor.append(x[1].text)
    except:
        processor.append(np.nan)
    try:    
        ram.append(x[2].text)
    except:
        ram.append(np.nan)
    try:
        battery.append(x[3].text)
    except:
        battery.append(np.nan)
    try:
        display.append(x[4].text)
    except:
        display.append(np.nan)
    try:
        camera.append(x[5].text)
    except:
        camera.append(np.nan)
    try:
        card.append(x[6].text)
    except:
        card.append(np.nan)
    try:
        os.append(x[7].text)
    except:
        os.append(np.nan)

# %%
len(names)
# Out:
# 980

# %%
len(prices)
# Out:
# 980

# %%
df = pd.DataFrame({
    'model':names,
    'price':prices,
    'rating':ratings,
    'sim':sim,
    'processor':processor,
    'ram':ram,
    'battery':battery,
    'display':display,
    'camera':camera,
    'card':card,
    'os':os
})

# %%
df.shape
# Out:
# (980, 11)

# %%
df
# Out:
#                                     model    price rating  \
# 0                    OnePlus Nord CE 4 5G  ₹24,999    NaN
# 1                 Motorola Edge 50 Pro 5G  ₹31,999    NaN
# 2                       OnePlus Nord 4 5G  ₹32,999    NaN
# 3                              Vivo T3 5G  ₹19,999    NaN
# 4               OnePlus Nord CE 4 Lite 5G  ₹20,990    NaN
# ..                                    ...      ...    ...
# 975  Samsung Galaxy F41 (6GB RAM + 128GB)  ₹17,490    NaN
# 976                        Gionee M12 Pro   ₹7,499     67
# 977                      Sony Xperia 5 II  ₹69,990    NaN
# 978                              OPPO F17  ₹17,290     78
# 979       Samsung Galaxy Note 20 Ultra 4G  ₹99,999    NaN
#
#                                                    sim  \
# 0                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1        Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 2    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 3                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ..                                                 ...
# 975                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 976                            Dual Sim, 3G, 4G, Wi-Fi
# 977            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 978                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 979                Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
#
#                                             processor  \
# 0    Snapdragon 7 Gen3, Octa Core, 2.63 GHz Processor
# 1    Snapdragon 7 Gen3, Octa Core, 2.63 GHz Processor
# 2    Snapdragon 7+ Gen3, Octa Core, 2.8 GHz Processor
# 3        Dimensity 7200, Octa Core, 2.8 GHz Processor
# 4     Snapdragon 7 Gen1, Octa Core, 2.4 GHz Processor
# ..                                                ...
# 975         Exynos 9611, Octa Core, 2.3 GHz Processor
# 976          Helio P60, Octa Core, 1.99 GHz Processor
# 977    Snapdragon 865 , Octa Core, 2.84 GHz Processor
# 978       Snapdragon 662 , Octa Core, 2 GHz Processor
# 979         Exynos 990, Octa Core, 2.73 GHz Processor
#
#                           ram                                   battery  \
# 0    8 GB RAM, 128 GB inbuilt  5500 mAh Battery with 100W Fast Charging
# 1    8 GB RAM, 256 GB inbuilt   4500 mAh Battery with 68W Fast Charging
# 2    8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 120W Fast Charging
# 3    8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 44W Fast Charging
# 4    8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 80W Fast Charging
# ..                        ...                                       ...
# 975  6 GB RAM, 128 GB inbuilt   6000 mAh Battery with 15W Fast Charging
# 976  6 GB RAM, 128 GB inbuilt                          4000 mAh Battery
# 977  8 GB RAM, 128 GB inbuilt   4000 mAh Battery with 21W Fast Charging
# 978  6 GB RAM, 128 GB inbuilt   4000 mAh Battery with 30W Fast Charging
# 979  8 GB RAM, 256 GB inbuilt   4500 mAh Battery with 25W Fast Charging
#
#                                                display  \
# 0    6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 1    6.7 inches, 1220 x 2712 px, 144 Hz Display wit...
# 2    6.78 inches, 1240 x 2772 px, 120 Hz Display wi...
# 3    6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4    6.74 inches, 1080 x 2400 px, 120 Hz Display wi...
# ..                                                 ...
# 975  6.4 inches, 1080 x 2340 px Display with Water ...
# 976  6.2 inches, 720 x 1520 px Display with Water D...
# 977         6.1 inches, 1080 x 2520 px, 120 Hz Display
# 978  6.44 inches, 1080 x 2400 px Display with Water...
# 979  6.9 inches, 1440 x 3088 px, 120 Hz Display wit...
#
#                                                 camera  \
# 0          50 MP + 8 MP Dual Rear & 16 MP Front Camera
# 1    50 MP + 13 MP + 10 MP Triple Rear & 50 MP Fron...
# 2    50 MP + 13 MP + 5 MP Triple Rear & 32 MP Front...
# 3        50 MP + 2 MP Triple Rear & 16 MP Front Camera
# 4    108 MP + 2 MP + 2 MP Triple Rear & 16 MP Front...
# ..                                                 ...
# 975  64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
# 976                    16 MP Rear & 13 MP Front Camera
# 977  12 MP + 12 MP + 12 MP Triple Rear & 8 MP Front...
# 978               16 MP Quad Rear & 16 MP Front Camera
# 979  108 MP + 12 MP + 12 MP Triple Rear & 10 MP Fro...
#
#                                    card             os
# 0       Memory Card (Hybrid), upto 1 TB    Android v14
# 1                           Android v14    No FM Radio
# 2                           Android v14    No FM Radio
# 3       Memory Card (Hybrid), upto 1 TB    Android v14
# 4       Memory Card (Hybrid), upto 1 TB    Android v14
# ..                                  ...            ...
# 975  Memory Card Supported, upto 512 GB  Android v10.0
# 976  Memory Card Supported, upto 256 GB    Android v10
# 977                Memory Card (Hybrid)    Android v10
# 978  Memory Card Supported, upto 256 GB    Android v10
# 979     Memory Card (Hybrid), upto 1 TB    Android v10
#
# [980 rows x 11 columns]
